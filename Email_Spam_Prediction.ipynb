# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import warnings
warnings.filterwarnings('ignore')
import string

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv("SMSSpamCollection.csv",sep="\t",names=["label","text"])
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   5572 non-null   object
#  1   text    5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
df.describe()
# Out:
#        label                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
df["label"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
df["label"].value_counts().plot.bar()

# %%
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'] = df["label"].map({'ham':0, 'spam':1})

# %%
df.head()
# Out:
#   label                                               text  target
# 0   ham  Go until jurong point, crazy.. Available only ...       0
# 1   ham                      Ok lar... Joking wif u oni...       0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...       1
# 3   ham  U dun say so early hor... U c already then say...       0
# 4   ham  Nah I don't think he goes to usf, he lives aro...       0

# %% [markdown]
# # Word Cloud

# %%
from wordcloud import WordCloud

# %%
import nltk
ps=nltk.PorterStemmer()

# %%
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))

# %%
spam_ = df[df["target"] == 1]["text"]
ham_= df[df["target"] == 0]["text"]

spam_words = []
ham_words = []

# Since this is just classifying the message as spam or ham, we can use isalpha(). 


def extractSpamWords(spamMessages):
    global spam_words
    words=" ".join(ps.stem(word) for word in spamMessages.split())
    words = [word.lower() for word in word_tokenize(spamMessages) if word.lower() not in stopwords and word.lower().isalpha()]
    spam_words = spam_words + words
    
def extractHamWords(hamMessages):
    global ham_words
    words=" ".join(ps.stem(word) for word in hamMessages.split())
    words = [word.lower() for word in word_tokenize(hamMessages) if word.lower() not in stopwords  and word.lower().isalpha()]
    ham_words = ham_words + words

spam_.apply(extractSpamWords)
ham_.apply(extractHamWords)
# Out:
# 0       None
# 1       None
# 3       None
# 4       None
# 6       None
#         ...
# 5565    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
# Name: text, Length: 4825, dtype: object

# %% [markdown]
# # Spam Word Cloud

# %%
spam_wordcloud = WordCloud(width=600, height=400).generate(" ".join(spam_words))
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(spam_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Ham Word Cloud

# %%
ham_wordcloud = WordCloud(width=600, height=400).generate(" ".join(ham_words))
plt.figure( figsize=(10,8), facecolor='k')
plt.imshow(ham_wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
spam_words = np.array(spam_words)
print("Top 10 Spam words are :")
pd.Series(spam_words).value_counts().head(10)
# Out:
# Top 10 Spam words are :
# call      346
# free      217
# txt       156
# u         145
# ur        144
# mobile    123
# text      121
# stop      118
# claim     113
# reply     104
# dtype: int64

# %%
ham_words = np.array(ham_words)
print("Top 10 Ham words are :")
pd.Series(ham_words).value_counts().head(10)
# Out:
# Top 10 Ham words are :
# u       991
# gt      318
# lt      316
# get     302
# go      249
# ur      247
# ok      247
# got     245
# know    235
# like    233
# dtype: int64

# %% [markdown]
# # Removing stopwords and other elements

# %%
def cleaning(msg):
    msg=msg.lower()
    msg=" ".join(word for word in msg.split() if word not in stopwords)
    msg=" ".join(ps.stem(word) for word in msg.split())
    msg = " ".join(word for word in msg.split() if word.isalpha())
    return msg

# %%
df['feature']=df['text'].apply(cleaning)

# %%
df.head()
# Out:
#   label                                               text  target  \
# 0   ham  Go until jurong point, crazy.. Available only ...       0
# 1   ham                      Ok lar... Joking wif u oni...       0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...       1
# 3   ham  U dun say so early hor... U c already then say...       0
# 4   ham  Nah I don't think he goes to usf, he lives aro...       0
#
#                                              feature
# 0  go jurong avail bugi n great world la e cine g...
# 1                                      ok joke wif u
# 2  free entri wkli comp win fa cup final tkt may ...
# 3                        u dun say earli u c alreadi
# 4                   nah think goe live around though

# %% [markdown]
# # Applying Scikit learn library

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['feature'], df['label'], test_size = 0.05, random_state = 41)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# instantiate the vectorizer
vect = CountVectorizer()
vect.fit(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
X_train_dtm = vect.transform(X_train)

# %%
X_train_dtm = vect.fit_transform(X_train)

# %%
X_train_dtm
# Out:
# <5293x4846 sparse matrix of type '<class 'numpy.int64'>'
# 	with 31766 stored elements in Compressed Sparse Row format>

# %%
print(vect.get_feature_names())
# Out:
# ['aa', 'aah', 'aaniy', 'aaooooright', 'abdomen', 'abil', 'abiola', 'abj', 'abl', 'abouta', 'abroad', 'absolut', 'abt', 'abta', 'abus', 'ac', 'academ', 'acc', 'accentur', 'accept', 'access', 'accid', 'accident', 'accommod', 'accommodationvouch', 'accordin', 'account', 'ach', 'achiev', 'acknowledg', 'across', 'act', 'actin', 'action', 'activ', 'actor', 'actual', 'ad', 'adam', 'add', 'addi', 'addict', 'address', 'adewal', 'adi', 'admin', 'administr', 'admir', 'admiss', 'admit', 'ador', 'adrian', 'adrink', 'adult', 'advanc', 'adventur', 'advic', 'advis', 'advisor', 'aeronaut', 'afew', 'affair', 'affection', 'affidavit', 'afford', 'afraid', 'african', 'aft', 'afternoon', 'aftr', 'ag', 'agalla', 'age', 'agenc', 'agent', 'ago', 'agre', 'ah', 'aha', 'ahead', 'ahmad', 'ahold', 'aid', 'aig', 'aight', 'aint', 'air', 'airport', 'airtel', 'aiya', 'aiyah', 'aiyar', 'aiyo', 'ajith', 'ak', 'aka', 'al', 'albi', 'album', 'alert', 'alett', 'alex', 'alfi', 'algarv', 'algebra', 'algorithm', 'ali', 'alian', 'all', 'allah', 'allalo', 'allow', 'almost', 'alon', 'along', 'alot', 'alreadi', 'alright', 'alrit', 'also', 'alter', 'although', 'alway', 'alwi', 'am', 'amanda', 'amaz', 'american', 'ami', 'ammo', 'amnow', 'among', 'amongst', 'amor', 'amount', 'amplikat', 'amrca', 'amrita', 'amt', 'an', 'ana', 'anal', 'analysi', 'anand', 'anderson', 'andr', 'andro', 'angel', 'angri', 'anim', 'anna', 'anni', 'anniversari', 'announc', 'annoy', 'anonym', 'anoth', 'ansr', 'answer', 'answerin', 'antelop', 'anti', 'antibiot', 'anybodi', 'anyhow', 'anymor', 'anyon', 'anyplac', 'anyth', 'anythi', 'anythin', 'anythingtomorrow', 'anytim', 'anyway', 'anywher', 'aom', 'apart', 'apeshit', 'apnt', 'apo', 'apolog', 'apologis', 'app', 'appar', 'appeal', 'appear', 'appendix', 'appi', 'applebe', 'appli', 'applic', 'appoint', 'appreci', 'approach', 'approv', 'approx', 'appt', 'april', 'aproach', 'apt', 'aptitud', 'aquariu', 'ar', 'arab', 'arabian', 'arcad', 'ard', 'area', 'arent', 'arestaur', 'aretak', 'argh', 'argu', 'argument', 'ari', 'aris', 'arithmet', 'arm', 'armand', 'armenia', 'arng', 'arnt', 'around', 'aroundn', 'arr', 'arrang', 'arrest', 'arriv', 'arrow', 'arsen', 'art', 'arti', 'arun', 'asa', 'asap', 'asda', 'ashley', 'ashwini', 'ask', 'askd', 'askin', 'asleep', 'ass', 'assess', 'assist', 'assum', 'asther', 'asthma', 'astn', 'astoundingli', 'astronom', 'asu', 'ate', 'athlet', 'athom', 'atlanta', 'atlast', 'atleast', 'atm', 'attach', 'attempt', 'atten', 'attend', 'attent', 'attitud', 'attract', 'attribut', 'auction', 'audiit', 'audit', 'audrey', 'audri', 'august', 'aunt', 'aunti', 'aust', 'authoris', 'auto', 'autocorrect', 'av', 'ava', 'avail', 'availa', 'avalarr', 'avatar', 'ave', 'aveng', 'avent', 'avenu', 'avin', 'avo', 'avoid', 'await', 'awak', 'award', 'away', 'awesom', 'aww', 'awww', 'ax', 'axi', 'ay', 'ayn', 'ayo', 'ba', 'babe', 'babi', 'babygoodby', 'babysit', 'bac', 'back', 'backdoor', 'bad', 'badass', 'badli', 'badrith', 'bag', 'bahama', 'baig', 'bailiff', 'bak', 'bakra', 'balanc', 'ball', 'bam', 'bambl', 'ban', 'band', 'bandag', 'bang', 'bangbab', 'bani', 'bank', 'banneduk', 'banter', 'bao', 'bar', 'bare', 'bari', 'barkley', 'barrel', 'barri', 'base', 'bash', 'basic', 'bat', 'batch', 'batchlor', 'bath', 'batt', 'batteri', 'bawl', 'bb', 'bbc', 'bbdelux', 'bbq', 'bc', 'bcaz', 'bcm', 'bcoz', 'bcum', 'bcz', 'bday', 'beach', 'bead', 'bear', 'beat', 'beauti', 'bec', 'becau', 'becausethey', 'becom', 'becoz', 'becz', 'bed', 'bedbut', 'bedreal', 'bedrm', 'bedroom', 'beeen', 'beendrop', 'beer', 'befor', 'beg', 'begin', 'begun', 'behalf', 'behav', 'behind', 'bein', 'believ', 'beliv', 'bell', 'bellearli', 'belli', 'belliger', 'belong', 'belov', 'belovd', 'ben', 'bend', 'beneath', 'beneficiari', 'benefit', 'benni', 'bergkamp', 'besid', 'best', 'bet', 'beth', 'betta', 'better', 'bettersn', 'bewar', 'beyond', 'bf', 'bfore', 'bhayandar', 'bian', 'bid', 'big', 'bigger', 'biggest', 'bill', 'billi', 'billion', 'bilo', 'bimbo', 'bin', 'biola', 'bird', 'birla', 'biro', 'birth', 'b ...

# %%
X_test_dtm = vect.transform(X_test)
X_test_dtm
# Out:
# <279x4846 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1438 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()
tfidf_transformer.fit(X_train_dtm)
tfidf_transformer.transform(X_train_dtm)
# Out:
# <5293x4846 sparse matrix of type '<class 'numpy.float64'>'
# 	with 31766 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Using Supprt Vector Machine

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm.fit(X_train_dtm, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = svm.predict(X_test_dtm)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.978494623655914

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[250   0]
#  [  6  23]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       250
#         spam       1.00      0.79      0.88        29
#
#     accuracy                           0.98       279
#    macro avg       0.99      0.90      0.94       279
# weighted avg       0.98      0.98      0.98       279

# %% [markdown]
# # Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
logreg.fit(X_train_dtm, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred1=logreg.predict(X_test_dtm)

# %%
print(accuracy_score(y_test, y_pred1))
# Out:
# 0.978494623655914

# %%
print(confusion_matrix(y_test, y_pred1))
# Out:
# [[249   1]
#  [  5  24]]

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       250
#         spam       0.96      0.83      0.89        29
#
#     accuracy                           0.98       279
#    macro avg       0.97      0.91      0.94       279
# weighted avg       0.98      0.98      0.98       279

# %% [markdown]
# # Using MultiNomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %%
nb.fit(X_train_dtm, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred2=nb.predict(X_test_dtm)

# %%
print(accuracy_score(y_test, y_pred2))
# Out:
# 0.967741935483871

# %%
print(confusion_matrix(y_test, y_pred2))
# Out:
# [[245   5]
#  [  4  25]]

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      0.98      0.98       250
#         spam       0.83      0.86      0.85        29
#
#     accuracy                           0.97       279
#    macro avg       0.91      0.92      0.91       279
# weighted avg       0.97      0.97      0.97       279

# %% [markdown]
# # Using GridSearch CV for HyperParameter Tuning in Support Vector Machine

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001]}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(X_train_dtm,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................................... C=0.1, gamma=1, total=   3.2s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.1s remaining:    0.0s
# [CV] ................................... C=0.1, gamma=1, total=   3.2s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   3.3s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   3.1s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   3.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   1.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   1.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   1.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   1.4s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   1.5s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................................ C=0.1, gamma=0.01, total=   1.2s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................................ C=0.1, gamma=0.01, total=   1.2s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................................ C=0.1, gamma=0.01, total=   1.1s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................................ C=0.1, gamma=0.01, total=   1.2s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ................................ C=0.1, gamma=0.01, total=   1.2s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ............................... C=0.1, gamma=0.001, total=   1.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ............................... C=0.1, gamma=0.001, total=   1.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ............................... C=0.1, gamma=0.001, total=   1.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ............................... C=0.1, gamma=0.001, total=   1.1s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ............................... C=0.1, gamma=0.001, total=   1.1s
# [CV] C=1, gamma=1 ....................................................
# [CV] ..................................... C=1, gamma=1, total=   3.3s
# [CV] C=1, gamma=1 ....................................................
# [CV] ..................................... C=1, gamma=1, total=   3.2s
# [CV] C=1, gamma=1 ....................................................
# [CV] ..................................... C=1, gamma=1, total=   3.3s
# [CV] C=1, gamma=1 ....................................................
# [CV] ..................................... C=1, gamma=1, total=   3.2s
# [CV] C=1, gamma=1 ....................................................
# [CV] ..................................... C=1, gamma=1, total=   3.3s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ................................... C=1, gamma=0.1, total=   1.4s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ................................... C=1, gamma=0.1, total=   1.3s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ................................... C=1, gamma=0.1, total=   1.3s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ................................... C=1, gamma=0.1, total=   1.3s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ................................... C=1, gamma=0.1, total=   1.3s
# [CV] C=1, gamma=0.01 .................................................
# [CV] .................................. C=1, gamma=0.01, total=   0.9s
# [CV] C=1, gamma=0.01 .................................................
# [CV] .................................. C=1, gamma=0.01, total=   0.9s
# [CV] C=1, gamma=0.01 .................................................
# [CV] .................................. C=1, gamma=0.01, total=   0.9s
# [CV] C=1, gamma=0.01 .................................................
# [CV] .................................. C=1, gamma=0.01, total=   1.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] .................................. C=1, gamma=0.01, total=   0.9s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ................................. C=1, gamma=0.001, total=   1.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ................................. C=1, gamma=0.001, total=   1.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ................................. C=1, gamma=0.001, total=   1.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ................................. C=1, gamma=0.001, total=   1.1s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ................................. C=1, gamma=0.001, total=   1.1s
# [CV] C=10, gamma=1 ...................................................
# [CV] .................................... C=10, gamma=1, total=   3.4s
# [CV] C=10, gamma=1 ...................................................
# [CV] .................................... C=10, gamma=1, total=   3.3s
# [CV] C=10, gamma=1 ...................................................
# [CV] .................................... C=10, gamma=1, total=   3.4s
# [CV] C=10, gamma=1 ...................................................
# [CV] .................................... C=10, gamma=1, total=   3.4s
# [CV] C=10, gamma=1 ...................................................
# [CV] .................................... C=10, gamma=1, total=   3.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] .................................. C=10, gamma=0.1, total=   1.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] .................................. C=10, gamma=0.1, total=   1.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] .................................. C=10, gamma=0.1, total=   1.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] .................................. C=10, gamma=0.1, total=   1.4s
# [CV] C=10, gamma=0.1 .................................................
# [CV] .................................. C=10, gamma=0.1, total=   1.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ................................. C=10, gamma=0.01, total=   0.8s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ................................. C=10, gamma=0.01, total=   0.7s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ................................. C=10, gamma=0.01, total=   0.7s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ................................. C=10, gamma=0.01, total=   0.8s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ................................. C=10, gamma=0.01, total=   0.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................................ C=10, gamma=0.001, total=   0.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................................ C=10, gamma=0.001, total=   0.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................................ C=10, gamma=0.001, total=   0.9s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................................ C=10, gamma=0.001, total=   0.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................................ C=10, gamma=0.001, total=   0.9s
# [CV] C=100, gamma=1 ..................................................
# [CV] ................................... C=100, gamma=1, total=   3.3s
# [CV] C=100, gamma=1 ..................................................
# [CV] ................................... C=100, gamma=1, total=   3.3s
# [CV] C=100, gamma=1 ..................................................
# [CV] ................................... C=100, gamma=1, total=   3.3s
# [CV] C=100, gamma=1 ..................................................
# [CV] ................................... C=100, gamma=1, total=   3.3s
# [CV] C=100, gamma=1 ..................................................
# [CV] ................................... C=100, gamma=1, total=   3.3s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ................................. C=100, gamma=0.1, total=   1.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ................................. C=100, gamma=0.1, total=   1.4s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ................................. C=100, gamma=0.1, total=   1.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ................................. C=100, gamma=0.1, total=   1.6s
# [CV] C=100, gamma=0.1 ................................................
# [CV] ................................. C=100, gamma=0.1, total=   1.6s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................................ C=100, gamma=0.01, total=   0.7s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................................ C=100, gamma=0.01, total=   0.6s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................................ C=100, gamma=0.01, total=   0.7s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................................ C=100, gamma=0.01, total=   0.7s
# [CV] C=100, gamma=0.01 ...............................................
# [CV] ................................ C=100, gamma=0.01, total=   0.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ............................... C=100, gamma=0.001, total=   0.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ............................... C=100, gamma=0.001, total=   0.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ............................... C=100, gamma=0.001, total=   0.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ............................... C=100, gamma=0.001, total=   0.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] ............................... C=100, gamma=0.001, total=   0.7s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  2.2min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': [1, 0.1, 0.01, 0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid.best_params_
# Out:
# {'C': 100, 'gamma': 0.001}

# %%
grid.best_estimator_
# Out:
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
grid_predictions = grid.predict(X_test_dtm)

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[250   0]
#  [  5  24]]

# %%
print(accuracy_score(y_test, grid_predictions))
# Out:
# 0.982078853046595

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       250
#         spam       1.00      0.83      0.91        29
#
#     accuracy                           0.98       279
#    macro avg       0.99      0.91      0.95       279
# weighted avg       0.98      0.98      0.98       279

# %% [markdown]
# # Creating a Model Using

# %%
import joblib

# %%
joblib.dump(grid, "ModelPrediction")
# Out:
# ['ModelPrediction']

# %% [markdown]
# # Using Tkinter

# %%
import pickle
import joblib
import tkinter as tk
from tkinter import *
from tkinter import messagebox

model = joblib.load("ModelPrediction")


def detect():
    user_input = t1.get()
    feature=model.predict(vect.transform([user_input]))
    if feature[0]=='ham':
        messagebox.showinfo("Result","Message is Safe ....  Not Spam......")
    else:
        messagebox.showinfo("Result","!!!!!!!Warning .... A Spam message is recived.....")

window = tk.Tk()
window.title("Spam Detection")
window.geometry('500x250')

l1= tk.Label(window, text="Enter the message", font = ('Algerian',20))
l1.place(x=100, y=20)

t1 = tk.Entry(window, width=70, border = 5)
t1.place(x=20, y=60)

b1 = tk.Button(window, text="Detect", font=('Algerian', 15), bg = "white", fg="black", command=detect)
b1.place(x=200, y=100)
b2 = tk.Button(window, text="Quit", font=("Algerian", 15), fg="red", bg = "white", command=quit)
b2.place(x=210, y=200)

window.mainloop()
